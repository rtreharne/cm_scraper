# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import getpass
import time
import os

# %%
gecko_driver_path = "C:/Users/treharne/Documents/cm_scraper/geckodriver.exe"

service = Service(gecko_driver_path)
options = Options()  # Add options if necessary
options.headless = True

browser = webdriver.Firefox()

browser.get("https://www.google.com")  # Test it!

# %%
import time
class CMSession:
    def __init__(self):
        # Get username and password from user
        self.username = input("Input your MWS username: ")
        self.password = getpass.getpass("Input your MWS password: ")


        self.browser = webdriver.Firefox()
        
        # Login
        self.browser.get('https://liverpool-curriculum.worktribe.com/')

        time.sleep(10)
        
        username_input = self.browser.find_element(By.XPATH, "//input[@id='username']")
        password_input = self.browser.find_element(By.XPATH, "//input[@id='password']")

        # Get submit button by text "LOG IN"
        submit_button = self.browser.find_element(By.CLASS_NAME, "form-button")
        
        username_input.send_keys(self.username)
        password_input.send_keys(self.password)
        
        submit_button.click()
        
        # Wait for 10 seconds
        print("wait ...")
        time.sleep(10)
        
        print("Verify your login by DUO")

# %%
session = CMSession()
# Out:
# wait ...
# Verify your login by DUO

# %%
session.browser.page_source
# Out:
# '<html lang="en"><head>\n<title>Worktribe</title>\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="Content-Language" content="en">\n    <meta name="description" content="">\n<meta name="keywords" content="">\n<meta name="robots" content="noindex">\n\n<meta name="xsrf_key" content="TpNf614g&amp;bOf!9lv2QMq!lQTP!xZfq4z">\n\n<!--\n<meta name="viewport" content="initial-scale=2.3, user-scalable=no" />\n<meta name="viewport" content="width=320; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;" />\n-->\n<link rel="icon" type="image/png" sizes="32x32" href="/resources/favicons/favicon-32x32.png">      <!--- 32px favicon -->\n<link rel="icon" type="image/png" sizes="16x16" href="/resources/favicons/favicon-16x16.png">      <!--- 16px favicon -->\n<link rel="icon" href="/resources/favicons/favicon.svg">                                           <!--- 1-colour SVG with internal styling for Chrome etc. -->\n<link rel="mask-icon" href="/resources/favicons/favicon.svg" color="#27323a">                      <!--- 1-colour SVG favicon for use with Safari, which has it\'s own type for SVG favicons -->\n<link rel="manifest" href="/resources/favicons/favicon.webmanifest">                               <!-- Web manifest for Android -->\n<link rel="apple-touch-icon" sizes="180x180" href="/resources/favicons/apple-touch-icon.png">      <!--- iOS icon -->\n\n<!--- CSS -->\n<link rel="stylesheet" href="/resources/css/worktribe.css?2024.7_bjasinh23hihih28" type="text/css">\n<link rel="stylesheet" href="/css.jx?cachestamp=1737489750&amp;2024.7_bjasinh23hihih28" type="text/css">\n<!--<link rel="stylesheet" href="/resources/fontawesome-free-5.11.2-web/css/all.css" type="text/css" />-->\n<style type="text/css" media="print">.noprint {display:none;}</style>\n\n<script type="text/javascript">\n    // Patch to allow jQuery to run outside of web browsers (e.g.: apps)\n    if (typeof module === \'object\') {window.module = module; module = undefined;}\n</script>\n\n<!-- JS -->\n<script type="text/javascript" src="/resources/jquery/js/jquery-3.7.0.min.js"></script>\n<script type="text/javascript" src="/resources/jquery/js/jquery-ui-1.13.2.min.js"></script>\n\n<!--<script type="text/javascript" src="/resources/javascripts/semantic.min.js"></script>-->\n<!-- SmartMenus jQuery plugin-->\n<script type="text/javascript" src="/resources/jquery/plugins/smartMenus/smartmenus.min.js?a=o"></script>\n\n<script type="text/javascript">\n    // Close patch\n    if (window.module) module = window.module;\n</script>\n\n<script type="text/javascript">\n    var organisation_name = \'University of Liverpool\';\n</script>\n\n<script type="text/javascript" src="/resources/javascripts/worktribe.js?2024.7_fpoeqjjpojd21"></script>\n<script type="text/javascript" src="/resources/javascripts/wtautocomplete.js?2024.7_fpoeqjjpojd21"></script>\n<script type="text/javascript" src="/resources/javascripts/record.js?2024.7_fpoeqjjpojd21"></script>\n<script type="text/javascript" src="/resources/javascripts/selection.js?a=rhgrpopjks"></script>\n\n\n    \n\n<script type="text/javascript">\n\nvar submitbuttonclicked = false;\n\n$().ready(function() {\n\n    $(\'.numberfield\').keyup(function(e) {\n\n        var ignore_keyCodes = [\n            37, // left arrow\n            16, // shift\n            39, // right arrow\n            91 // cmd\n        ];\n        if ( ignore_keyCodes.indexOf( e.keyCode ) < 0 ) $(this).val(validatenumber($(this).val()));\n\n    });\n\n\t$(\'.wt-table-sortable\').sortable({\n        helper: matchCurrentWidth,\n\t\thandle: \'span.moveicon\',\n\t\tstart:function( event,ui ) {\n\t\t\t$(\'#\'+ui.item.attr(\'id\')).css({backgroundColor:\'#eeeeee\'});\n\t\t},\n\t\tupdate:function( event,ui ) {\n\n\t\t\tmoveafterrecordid = 0;\n\n            if (ui.item.hasClass(\'qsrecord\') ) {\n                recordid = ui.item.attr(\'linkedqsrecordid\');\n                moveafterrecordid = ui.item.prev(\'tr\').attr(\'linkedqsrecordid\');\ ...

# %%
from main import *

# %%
session = CMSession()
# Out:
# wait ...
# wait ...
# Verification code for DUO
# 4331
# You have 1 seconds to enter your verification code..
# Login Success.

# %%
url = "https://liverpool-curriculum.worktribe.com/selection.jx?selectionid=79582"

# %%
courses = get_courses(session, url)
